# %%
import pandas as pd
import urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup
import math

# %%
import warnings
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas.tools.plotting import autocorrelation_plot
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
import operator

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages

# %%
# %matplotlib inline

# %%
def readFile(filename):    
    print("=====VA: Total Personal Income File=====")
    dateparse = lambda dates: pd.datetime.strptime(dates, '%Y')
    df_1 = pd.read_csv(filename, header=0,parse_dates=[0],index_col=0,date_parser=dateparse)
    print("File read into dataframe.")
    print(df_1.shape)
    df_1 = df_1.sort()
    return df_1

# %%
df_VA = readFile("VA_TotalPersonalIncome.csv")
# Out:
# =====VA: Total Personal Income File=====
# File read into dataframe.
# (39, 1)

# %%
df_VA.index
# Out:
# DatetimeIndex(['1977-01-01', '1978-01-01', '1979-01-01', '1980-01-01',
#                '1981-01-01', '1982-01-01', '1983-01-01', '1984-01-01',
#                '1985-01-01', '1986-01-01', '1987-01-01', '1988-01-01',
#                '1989-01-01', '1990-01-01', '1991-01-01', '1992-01-01',
#                '1993-01-01', '1994-01-01', '1995-01-01', '1996-01-01',
#                '1997-01-01', '1998-01-01', '1999-01-01', '2000-01-01',
#                '2001-01-01', '2002-01-01', '2003-01-01', '2004-01-01',
#                '2005-01-01', '2006-01-01', '2007-01-01', '2008-01-01',
#                '2009-01-01', '2010-01-01', '2011-01-01', '2012-01-01',
#                '2013-01-01', '2014-01-01', '2015-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
df_VA.head()
# Out:
#             VA_Total Personal Income
# 1977-01-01                   39623.2
# 1978-01-01                   44964.2
# 1979-01-01                   50089.2
# 1980-01-01                   56563.5
# 1981-01-01                   63482.5

# %%
df_VA.rename(columns={'VA_Total Personal Income': 'VA_TotalPersonalIncome'}, inplace=True)

# %%
df_VA.VA_TotalPersonalIncome.describe()
# Out:
# count        39.000000
# mean     206050.651282
# std      123704.744934
# min       39623.200000
# 25%      100442.050000
# 50%      175267.500000
# 75%      314308.150000
# max      437111.400000
# Name: VA_TotalPersonalIncome, dtype: float64

# %%
df_VA.plot(figsize=(15,6))
plt.show()
#fig.savefig('DC_TotalPersonalIncome.png', dpi=150)

# %% [markdown]
# There is an overall increasing trend in the data.

# %%
#Further Decompose time-series into trend, seasionality and noise
def decompose(df):
    decomposition = sm.tsa.seasonal_decompose(df, model='additive')
    fig = decomposition.plot()
    plt.show()
    #fig.savefig('Seasonal_Decompose.png', dpi=150)

# %%
decompose(df_VA)

# %% [markdown]
# # Stationarity

# %% [markdown]
# We are taking two techniques to check if the dataset is stationary or not.
# First, check the mean and variance.
# Second, Dickey-Fuller test.
#
# Plotting Rolling Statistics: We can plot the moving average or moving variance and see if it varies with time. By moving average/variance I mean that at any instant ‘t’, we’ll take the average/variance of the last year, i.e. last 12 months. But again this is more of a visual technique.
#
# Dickey-Fuller Test: This is one of the statistical tests for checking stationarity. Here the null hypothesis is that the TS is non-stationary. The test results comprise of a Test Statistic and some Critical Values for difference confidence levels.
# If the ‘Test Statistic’ is less than the ‘Critical Value’, we can reject the null hypothesis and say that the series is stationary. Refer this article for details.

# %%
#Split the dataset and calculate the mean and variance for each group.
def meanVarianceCheck(df):
    X = df.values
    split = len(X) / 2
    X1, X2 = X[0:split], X[split:]
    mean1, mean2 = X1.mean(), X2.mean()
    var1, var2 = X1.var(), X2.var()
    return ('mean1=%f, mean2=%f' % (mean1, mean2), 'variance1=%f, variance2=%f' % (var1, var2))

# %%
meanVarianceCheck(df_VA)
# Out:
# ('mean1=99687.547368, mean2=307095.600000',
#  'variance1=1571446138.111967, variance2=6625031573.307001')

# %%
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=5)
    rolstd = pd.rolling_std(timeseries, window=5)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(df_VA.VA_TotalPersonalIncome)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  1.809536
# p-value                         0.998368
# #Lags Used                      9.000000
# Number of Observations Used    29.000000
# Critical Value (10%)           -2.623158
# Critical Value (1%)            -3.679060
# Critical Value (5%)            -2.967882
# dtype: float64

# %% [markdown]
# # Estimating & Eliminating Trend

# %%
#log transform
def logTransform(df):
    ts_log = np.log(df)
    plt.plot(ts_log)
    return ts_log

# %%
ts_log = logTransform(df_VA)

# %%
test_stationarity(ts_log.VA_TotalPersonalIncome)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.848926
# p-value                         0.002445
# #Lags Used                      2.000000
# Number of Observations Used    36.000000
# Critical Value (10%)           -2.611671
# Critical Value (1%)            -3.626652
# Critical Value (5%)            -2.945951
# dtype: float64

# %%
def logFirstDifference(ts_log):
    ts_log_diff = ts_log - ts_log.shift()
    ts_log_diff.dropna(inplace=True)
    return ts_log_diff

# %%
ts_log_diff = logFirstDifference(ts_log)
test_stationarity(ts_log_diff.VA_TotalPersonalIncome)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.694619
# p-value                         0.074974
# #Lags Used                      1.000000
# Number of Observations Used    36.000000
# Critical Value (10%)           -2.611671
# Critical Value (1%)            -3.626652
# Critical Value (5%)            -2.945951
# dtype: float64

# %%
def firstDifference(df):
    ts_first_diff = df - df.shift()
    ts_first_diff.dropna(inplace=True)
    return ts_first_diff

# %%
ts_first_diff = firstDifference(df_VA)

# %%
test_stationarity(ts_first_diff.VA_TotalPersonalIncome)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.618484
# p-value                         0.473524
# #Lags Used                      8.000000
# Number of Observations Used    29.000000
# Critical Value (10%)           -2.623158
# Critical Value (1%)            -3.679060
# Critical Value (5%)            -2.967882
# dtype: float64

# %%
#Decomposition
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
ts_log_decompose = trend
ts_log_decompose.dropna(inplace=True)
test_stationarity(ts_log_decompose.VA_TotalPersonalIncome)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.848926
# p-value                         0.002445
# #Lags Used                      2.000000
# Number of Observations Used    36.000000
# Critical Value (10%)           -2.611671
# Critical Value (1%)            -3.626652
# Critical Value (5%)            -2.945951
# dtype: float64

# %% [markdown]
# # Forecasting a Time Series

# %%
lag_acf = acf(ts_log, nlags=10)
lag_pacf = pacf(ts_log, nlags=10, method='ols')

# %%
autocorrelation_plot(ts_log)

# %%
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
aic_metric = pd.DataFrame({'Modelname':[],'AIC':[]})
aic_dict = {}

# %%
def cal_aic_metric(modelname,model):
    global aic_metric
    AIC = model.aic
    aic_dict[modelname] = AIC
    df_error = pd.DataFrame({'Modelname':[modelname],'AIC':[AIC]})
    aic_metric = pd.concat([aic_metric,df_error])
    return aic_metric

# %%
def AR_Model(ts):
    model = ARIMA(ts, order=(2, 0, 0))
    results_AR = model.fit(disp=0)
    cal_aic_metric('ARIMA(ts, order=2, 0, 0))',results_AR)
    print('Lag: %s' % results_AR.k_ar)
    print('Coefficients: %s' % results_AR.params)
    print(results_AR.summary())
    plt.plot(ts)
    plt.plot(results_AR.fittedvalues, color='red')
    return results_AR

# %%
model_AR = AR_Model(ts_log)
# Out:
# Lag: 2
# Coefficients: const                           11.407055
# ar.L1.VA_TotalPersonalIncome     1.954178
# ar.L2.VA_TotalPersonalIncome    -0.956219
# dtype: float64
#                                 ARMA Model Results
# ==================================================================================
# Dep. Variable:     VA_TotalPersonalIncome   No. Observations:                   39
# Model:                         ARMA(2, 0)   Log Likelihood                  88.720
# Method:                           css-mle   S.D. of innovations              0.022
# Date:                    Thu, 27 Apr 2017   AIC                           -169.439
# Time:                            19:05:09   BIC                           -162.785
# Sample:                        01-01-1977   HQIC                          -167.052
#                              - 01-01-2015
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           11.4071      1.238      9.214      0.000       8.981      13.834
# ar.L1.VA_TotalPersonalIncome     1.9542      0.035     56.119      0.000       1.886       2.022
# ar.L2.VA_TotalPersonalIncome    -0.9562      0.035    -27.129      0.000      -1.025      -0.887
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0218           -0.0407j            1.0226           -0.0063
# AR.2            1.0218           +0.0407j            1.0226            0.0063
# -----------------------------------------------------------------------------

# %%
def MA_Model(ts):
    model = ARIMA(ts_log, order=(0, 0, 5))  
    results_MA = model.fit(disp=0)
    cal_aic_metric('ARIMA(ts, order=(0, 0, 5))',results_MA)
    print('Lag: %s' % results_MA.k_ar)
    print('Coefficients: %s' % results_MA.params)
    print(results_MA.summary())
    plt.plot(ts)
    plt.plot(results_MA.fittedvalues, color='red')
    return results_MA

# %%
model_MA = MA_Model(ts_log)
# Out:
# Lag: 0
# Coefficients: const                           11.981601
# ma.L1.VA_TotalPersonalIncome     3.241485
# ma.L2.VA_TotalPersonalIncome     5.285071
# ma.L3.VA_TotalPersonalIncome     5.163671
# ma.L4.VA_TotalPersonalIncome     3.045829
# ma.L5.VA_TotalPersonalIncome     0.859691
# dtype: float64
#                                 ARMA Model Results
# ==================================================================================
# Dep. Variable:     VA_TotalPersonalIncome   No. Observations:                   39
# Model:                         ARMA(0, 5)   Log Likelihood                  49.074
# Method:                           css-mle   S.D. of innovations              0.055
# Date:                    Thu, 27 Apr 2017   AIC                            -84.147
# Time:                            19:05:41   BIC                            -72.502
# Sample:                        01-01-1977   HQIC                           -79.969
#                              - 01-01-2015
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           11.9816      0.155     77.467      0.000      11.678      12.285
# ma.L1.VA_TotalPersonalIncome     3.2415        nan        nan        nan         nan         nan
# ma.L2.VA_TotalPersonalIncome     5.2851        nan        nan        nan         nan         nan
# ma.L3.VA_TotalPersonalIncome     5.1637        nan        nan        nan         nan         nan
# ma.L4.VA_TotalPersonalIncome     3.0458        nan        nan        nan         nan         nan
# ma.L5.VA_TotalPersonalIncome     0.8597        nan        nan        nan         nan         nan
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -0.3838           -0.9243j            1.0008           -0.3126
# MA.2           -0.3838           +0.9243j            1.0008            0.3126
# MA.3           -1.1613           -0.0000j            1.1613           -0.5000
# MA.4           -0.8070           -0.5906j            1.0000           -0.3995
# MA.5           -0.8070           +0.5906j            1.0000            0.3995
# -----------------------------------------------------------------------------

# %%
def Combined_Model(ts):
    model = ARIMA(ts_log, order=(1, 0, 1))  
    results_ARIMA = model.fit(disp=0)
    cal_aic_metric('ARIMA(ts, order=(1, 0, 1))',results_ARIMA)
    print('Lag: %s' % results_ARIMA.k_ar)
    print('Coefficients: %s' % results_ARIMA.params)
    print(results_ARIMA.summary())
    plt.plot(ts)
    plt.plot(results_ARIMA.fittedvalues, color='red')
    return results_ARIMA

# %%
model_combined = Combined_Model(ts_log)
# Out:
# Lag: 1
# Coefficients: const                           11.759032
# ar.L1.VA_TotalPersonalIncome     0.997911
# ma.L1.VA_TotalPersonalIncome     0.850329
# dtype: float64
#                                 ARMA Model Results
# ==================================================================================
# Dep. Variable:     VA_TotalPersonalIncome   No. Observations:                   39
# Model:                         ARMA(1, 1)   Log Likelihood                  64.263
# Method:                           css-mle   S.D. of innovations              0.042
# Date:                    Thu, 27 Apr 2017   AIC                           -120.525
# Time:                            19:06:25   BIC                           -113.871
# Sample:                        01-01-1977   HQIC                          -118.138
#                              - 01-01-2015
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           11.7590      1.180      9.962      0.000       9.445      14.073
# ar.L1.VA_TotalPersonalIncome     0.9979      0.003    337.869      0.000       0.992       1.004
# ma.L1.VA_TotalPersonalIncome     0.8503      0.072     11.770      0.000       0.709       0.992
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0021           +0.0000j            1.0021            0.0000
# MA.1           -1.1760           +0.0000j            1.1760            0.5000
# -----------------------------------------------------------------------------

# %%
aic_metric
# Out:
#           AIC                   Modelname
# 0 -169.439467   ARIMA(ts, order=2, 0, 0))
# 0  -84.147116  ARIMA(ts, order=(0, 0, 5))
# 0 -120.525084  ARIMA(ts, order=(1, 0, 1))

# %%
aic_dict
# Out:
# {'ARIMA(ts, order=(0, 0, 5))': -84.14711588461992,
#  'ARIMA(ts, order=(1, 0, 1))': -120.52508368737043,
#  'ARIMA(ts, order=2, 0, 0))': -169.43946688084506}

# %%
#### Calculate best model
best_model =  min(aic_dict.items(),key=operator.itemgetter(1))[0]
print('Best Model is ', best_model)
# Out:
# Best Model is  ARIMA(ts, order=2, 0, 0))

# %%
#Forecast using Best Model
def forecast(model,numSteps):
    #model.forecast(steps=numSteps)
    output = model.forecast(steps=numSteps)[0]
    output.tolist()
    output = np.exp(output)
    print(output)
    return output

# %%
output_forecast = forecast(model_combined,5)
# Out:
# [ 434078.90842796  432972.36411235  431870.94311921  430774.61588841
#   429683.35306283]

# %%
#AR Model
#model = ARIMA(ts_log, order=(2, 1, 0))
#results_AR = model.fit(disp=0)  
#print(results_AR.summary())
#print('Lag: %s' % results_AR.k_ar)
#print('Coefficients: %s' % results_AR.params)
#plt.plot(ts_log_diff)
#plt.plot(results_AR.fittedvalues, color='red')
#print(results_AR.aic)
#plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-ts_log_diff)**2))


#MA Model
#model = ARIMA(ts_log, order=(0, 1, 5))  
#results_MA = model.fit(disp=-1)  
#print('Lag: %s' % results_MA.k_ar)
#print('Coefficients: %s' % results_MA.params)
#print(results_MA.summary())
#plt.plot(ts_log_diff)
#plt.plot(results_MA.fittedvalues, color='red')
#plt.title('RSS: %.4f'% sum((results_MA.fittedvalues-ts_log_diff)**2))



#Combined Model
#model = ARIMA(ts_log, order=(2, 1,2))  
#results_ARIMA = model.fit(disp=-1)
#print('Lag: %s' % results_ARIMA.k_ar)
#print('Coefficients: %s' % results_ARIMA.params)
#print(results_ARIMA.summary())
#plt.plot(ts_log_diff)
#plt.plot(results_ARIMA.fittedvalues, color='red')
