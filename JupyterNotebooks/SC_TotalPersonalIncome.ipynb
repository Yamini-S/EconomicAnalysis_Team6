# %%
import pandas as pd
import urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup
import math

# %%
import warnings
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas.tools.plotting import autocorrelation_plot
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
import operator

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages

# %%
# %matplotlib inline

# %%
def readFile(filename):
    dateparse = lambda dates: pd.datetime.strptime(dates, '%Y')
    df_1 = pd.read_csv(filename, header=0,parse_dates=[0],index_col=0,date_parser=dateparse)
    print("File read into dataframe.")
    print(df_1.shape)
    df_1 = df_1.sort()
    print("=====Total Personal Income File=====")
    return df_1

# %%
df_SC = readFile("SC_TotalPersonalIncome.csv")
# Out:
# File read into dataframe.
# (39, 1)
# =====Total Personal Income File=====

# %%
df_SC.index
# Out:
# DatetimeIndex(['1977-01-01', '1978-01-01', '1979-01-01', '1980-01-01',
#                '1981-01-01', '1982-01-01', '1983-01-01', '1984-01-01',
#                '1985-01-01', '1986-01-01', '1987-01-01', '1988-01-01',
#                '1989-01-01', '1990-01-01', '1991-01-01', '1992-01-01',
#                '1993-01-01', '1994-01-01', '1995-01-01', '1996-01-01',
#                '1997-01-01', '1998-01-01', '1999-01-01', '2000-01-01',
#                '2001-01-01', '2002-01-01', '2003-01-01', '2004-01-01',
#                '2005-01-01', '2006-01-01', '2007-01-01', '2008-01-01',
#                '2009-01-01', '2010-01-01', '2011-01-01', '2012-01-01',
#                '2013-01-01', '2014-01-01', '2015-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
df_SC.head()
# Out:
#             SC_Total Personal Income
# 1977-01-01                   17515.2
# 1978-01-01                   19786.9
# 1979-01-01                   22172.3
# 1980-01-01                   24830.8
# 1981-01-01                   27941.2

# %%
df_SC.rename(columns={'SC_Total Personal Income': 'SC_TotalPersonalIncome'}, inplace=True)

# %%
df_SC.SC_TotalPersonalIncome.describe()
# Out:
# count        39.000000
# mean      87897.948718
# std       51505.391727
# min       17515.200000
# 25%       42652.250000
# 50%       78254.100000
# 75%      130721.400000
# max      186285.700000
# Name: SC_TotalPersonalIncome, dtype: float64

# %%
df_SC.plot(figsize=(15,6))
plt.show()
#fig.savefig('DC_TotalPersonalIncome.png', dpi=150)

# %% [markdown]
# There is an overall increasing trend in the data.

# %%
#Further Decompose time-series into trend, seasionality and noise
def decompose(df):
    decomposition = sm.tsa.seasonal_decompose(df, model='additive')
    fig = decomposition.plot()
    plt.show()
    #fig.savefig('Seasonal_Decompose.png', dpi=150)

# %%
decompose(df_SC)

# %% [markdown]
# # Stationarity

# %% [markdown]
# We are taking two techniques to check if the dataset is stationary or not.
# First, check the mean and variance.
# Second, Dickey-Fuller test.
#
# Plotting Rolling Statistics: We can plot the moving average or moving variance and see if it varies with time. By moving average/variance I mean that at any instant ‘t’, we’ll take the average/variance of the last year, i.e. last 12 months. But again this is more of a visual technique.
#
# Dickey-Fuller Test: This is one of the statistical tests for checking stationarity. Here the null hypothesis is that the TS is non-stationary. The test results comprise of a Test Statistic and some Critical Values for difference confidence levels.
# If the ‘Test Statistic’ is less than the ‘Critical Value’, we can reject the null hypothesis and say that the series is stationary. Refer this article for details.

# %%
#Split the dataset and calculate the mean and variance for each group.

def meanVarianceCheck(df):
    X = df.values
    split = len(X) / 2
    X1, X2 = X[0:split], X[split:]
    mean1, mean2 = X1.mean(), X2.mean()
    var1, var2 = X1.var(), X2.var()
    return ('mean1=%f, mean2=%f' % (mean1, mean2), 'variance1=%f, variance2=%f' % (var1, var2))

# %%
meanVarianceCheck(df_SC)
# Out:
# ('mean1=43141.647368, mean2=130416.435000',
#  'variance1=293738995.915125, variance2=1050486309.329275')

# %%
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=5)
    rolstd = pd.rolling_std(timeseries, window=5)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(df_SC.SC_TotalPersonalIncome)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.944861
# p-value                         0.772841
# #Lags Used                     10.000000
# Number of Observations Used    28.000000
# Critical Value (10%)           -2.625296
# Critical Value (5%)            -2.971989
# Critical Value (1%)            -3.688926
# dtype: float64

# %% [markdown]
# # Estimating & Eliminating Trend

# %%
#log transform
def logTransform(df):
    ts_log = np.log(df)
    plt.plot(ts_log)
    return ts_log

# %%
ts_log = logTransform(df_SC)

# %%
test_stationarity(ts_log.SC_TotalPersonalIncome)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.613842
# p-value                         0.475959
# #Lags Used                     10.000000
# Number of Observations Used    28.000000
# Critical Value (10%)           -2.625296
# Critical Value (5%)            -2.971989
# Critical Value (1%)            -3.688926
# dtype: float64

# %%
def logFirstDifference(ts_log):
    ts_log_diff = ts_log - ts_log.shift()
    ts_log_diff.dropna(inplace=True)
    return ts_log_diff

# %%
ts_log_diff = logFirstDifference(ts_log)
test_stationarity(ts_log_diff.SC_TotalPersonalIncome)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.464265
# p-value                         0.551109
# #Lags Used                      9.000000
# Number of Observations Used    28.000000
# Critical Value (10%)           -2.625296
# Critical Value (5%)            -2.971989
# Critical Value (1%)            -3.688926
# dtype: float64

# %%
def firstDifference(df):
    ts_first_diff = df - df.shift()
    ts_first_diff.dropna(inplace=True)
    return ts_first_diff

# %%
ts_first_diff = firstDifference(df_SC)

# %%
test_stationarity(ts_first_diff.SC_TotalPersonalIncome)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.812666
# p-value                         0.815373
# #Lags Used                      9.000000
# Number of Observations Used    28.000000
# Critical Value (10%)           -2.625296
# Critical Value (5%)            -2.971989
# Critical Value (1%)            -3.688926
# dtype: float64

# %%
#Decomposition
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
ts_log_decompose = trend
ts_log_decompose.dropna(inplace=True)
test_stationarity(ts_log_decompose.SC_TotalPersonalIncome)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.613842
# p-value                         0.475959
# #Lags Used                     10.000000
# Number of Observations Used    28.000000
# Critical Value (10%)           -2.625296
# Critical Value (5%)            -2.971989
# Critical Value (1%)            -3.688926
# dtype: float64

# %% [markdown]
# # Forecasting a Time Series

# %%
lag_acf = acf(ts_log, nlags=10)
lag_pacf = pacf(ts_log, nlags=10, method='ols')

# %%
autocorrelation_plot(ts_log)

# %%
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
aic_metric = pd.DataFrame({'Modelname':[],'AIC':[]})
aic_dict = {}

# %%
def cal_aic_metric(modelname,model):
    global aic_metric
    AIC = model.aic
    aic_dict[modelname] = AIC
    df_error = pd.DataFrame({'Modelname':[modelname],'AIC':[AIC]})
    aic_metric = pd.concat([aic_metric,df_error])
    return aic_metric

# %%
def AR_Model(ts):
    model = ARIMA(ts, order=(2, 0, 0))
    results_AR = model.fit(disp=0)
    cal_aic_metric('ARIMA(ts, order=(2, 0, 0))',results_AR)
    print('Lag: %s' % results_AR.k_ar)
    print('Coefficients: %s' % results_AR.params)
    print(results_AR.summary())
    plt.plot(ts)
    plt.plot(results_AR.fittedvalues, color='red')
    return results_AR

# %%
model_AR = AR_Model(ts_log)
# Out:
# Lag: 2
# Coefficients: const                           10.682803
# ar.L1.SC_TotalPersonalIncome     1.944082
# ar.L2.SC_TotalPersonalIncome    -0.946160
# dtype: float64
#                                 ARMA Model Results
# ==================================================================================
# Dep. Variable:     SC_TotalPersonalIncome   No. Observations:                   39
# Model:                         ARMA(2, 0)   Log Likelihood                  85.918
# Method:                           css-mle   S.D. of innovations              0.023
# Date:                    Thu, 27 Apr 2017   AIC                           -163.835
# Time:                            18:51:16   BIC                           -157.181
# Sample:                        01-01-1977   HQIC                          -161.448
#                              - 01-01-2015
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           10.6828      1.222      8.745      0.000       8.288      13.077
# ar.L1.SC_TotalPersonalIncome     1.9441      0.041     47.904      0.000       1.865       2.024
# ar.L2.SC_TotalPersonalIncome    -0.9462      0.041    -23.041      0.000      -1.027      -0.866
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0274           -0.0381j            1.0281           -0.0059
# AR.2            1.0274           +0.0381j            1.0281            0.0059
# -----------------------------------------------------------------------------

# %%
def MA_Model(ts):
    model = ARIMA(ts_log, order=(0, 0, 7))  
    results_MA = model.fit(disp=0)
    cal_aic_metric('ARIMA(ts, order=(0, 0, 7))',results_MA)
    print('Lag: %s' % results_MA.k_ar)
    print('Coefficients: %s' % results_MA.params)
    print(results_MA.summary())
    plt.plot(ts)
    plt.plot(results_MA.fittedvalues, color='red')
    return results_MA

# %%
model_MA = MA_Model(ts_log)
# Out:
# Lag: 0
# Coefficients: const                           11.143771
# ma.L1.SC_TotalPersonalIncome     2.836183
# ma.L2.SC_TotalPersonalIncome     4.784492
# ma.L3.SC_TotalPersonalIncome     5.942204
# ma.L4.SC_TotalPersonalIncome     5.838898
# ma.L5.SC_TotalPersonalIncome     4.441074
# ma.L6.SC_TotalPersonalIncome     2.497677
# ma.L7.SC_TotalPersonalIncome     0.702608
# dtype: float64
#                                 ARMA Model Results
# ==================================================================================
# Dep. Variable:     SC_TotalPersonalIncome   No. Observations:                   39
# Model:                         ARMA(0, 7)   Log Likelihood                  60.614
# Method:                           css-mle   S.D. of innovations              0.040
# Date:                    Thu, 27 Apr 2017   AIC                           -103.228
# Time:                            18:51:50   BIC                            -88.256
# Sample:                        01-01-1977   HQIC                           -97.856
#                              - 01-01-2015
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           11.1438      0.167     66.837      0.000      10.817      11.471
# ma.L1.SC_TotalPersonalIncome     2.8362      0.172     16.526      0.000       2.500       3.173
# ma.L2.SC_TotalPersonalIncome     4.7845      0.475     10.064      0.000       3.853       5.716
# ma.L3.SC_TotalPersonalIncome     5.9422      0.759      7.825      0.000       4.454       7.431
# ma.L4.SC_TotalPersonalIncome     5.8389      0.868      6.725      0.000       4.137       7.541
# ma.L5.SC_TotalPersonalIncome     4.4411      0.745      5.958      0.000       2.980       5.902
# ma.L6.SC_TotalPersonalIncome     2.4977      0.472      5.294      0.000       1.573       3.422
# ma.L7.SC_TotalPersonalIncome     0.7026      0.169      4.150      0.000       0.371       1.034
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            0.2215           -0.9752j            1.0000           -0.2145
# MA.2            0.2215           +0.9752j            1.0000            0.2145
# MA.3           -0.4036           -0.9158j            1.0008           -0.3161
# MA.4           -0.4036           +0.9158j            1.0008            0.3161
# MA.5           -0.8848           -0.4661j            1.0000           -0.4228
# MA.6           -0.8848           +0.4661j            1.0000            0.4228
# MA.7           -1.4211           -0.0000j            1.4211           -0.5000
# -----------------------------------------------------------------------------

# %%
def Combined_Model(ts):
    model = ARIMA(ts_log, order=(5, 0, 2))  
    results_ARIMA = model.fit(disp=0)
    cal_aic_metric('ARIMA(ts, order=(5, 0, 2))',results_ARIMA)
    print('Lag: %s' % results_ARIMA.k_ar)
    print('Coefficients: %s' % results_ARIMA.params)
    print(results_ARIMA.summary())
    plt.plot(ts)
    plt.plot(results_ARIMA.fittedvalues, color='red')
    return results_ARIMA

# %%
#model_Combined = Combined_Model(ts_log)

# %%
aic_metric
# Out:
#           AIC                   Modelname
# 0 -163.835110  ARIMA(ts, order=(2, 0, 0))
# 0 -103.227879  ARIMA(ts, order=(0, 0, 7))

# %%
aic_dict
# Out:
# {'ARIMA(ts, order=(0, 0, 7))': -103.22787925028402,
#  'ARIMA(ts, order=(2, 0, 0))': -163.83510976057002}

# %%
#### Calculate best model
best_model =  min(aic_dict.items(),key=operator.itemgetter(1))[0]
print('Best Model is ', best_model)
# Out:
# Best Model is  ARIMA(ts, order=(2, 0, 0))

# %%
#Forecast using Best Model
def forecast(model,numSteps):
    #model.forecast(steps=numSteps)
    output = model.forecast(steps=numSteps)[0]
    output.tolist()
    output = np.exp(output)
    print(output)
    return output

# %%
output_forecast = forecast(model_AR,5)
# Out:
# [ 194678.13087527  202336.28622872  209190.85921048  215187.50467525
#   220287.29753853]

# %%
#AR Model
#model = ARIMA(ts_log, order=(2, 1, 0))
#results_AR = model.fit(disp=0)  
#print(results_AR.summary())
#print('Lag: %s' % results_AR.k_ar)
#print('Coefficients: %s' % results_AR.params)
#plt.plot(ts_log_diff)
#plt.plot(results_AR.fittedvalues, color='red')
#print(results_AR.aic)
#plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-ts_log_diff)**2))



#MA Model
#model = ARIMA(ts_log, order=(0, 1, 5))  
#results_MA = model.fit(disp=-1)  
#print('Lag: %s' % results_MA.k_ar)
#print('Coefficients: %s' % results_MA.params)
#print(results_MA.summary())
#plt.plot(ts_log_diff)
#plt.plot(results_MA.fittedvalues, color='red')
#plt.title('RSS: %.4f'% sum((results_MA.fittedvalues-ts_log_diff)**2))


#Combined Model
#model = ARIMA(ts_log, order=(2, 1,2))  
#results_ARIMA = model.fit(disp=-1)
#print('Lag: %s' % results_ARIMA.k_ar)
#print('Coefficients: %s' % results_ARIMA.params)
#print(results_ARIMA.summary())
#plt.plot(ts_log_diff)
#plt.plot(results_ARIMA.fittedvalues, color='red')
